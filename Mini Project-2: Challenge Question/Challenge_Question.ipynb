# %% [markdown]
# <a href="https://colab.research.google.com/github/AryanK0/Thapar-Summer-School/blob/main/Mini%20Project-2%3A%20Challenge%20Question/Challenge_Question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
l = ["Ram", 1, "Shyam", 2, "Aman", 3]
l1 = []
l2 = []

for i in l:
  if (type(i) == int):
    l1.append(i)
  else:
    l2.append(i)

l1.sort
l2.sort
print(l1 + l2)
# Out:
# [1, 2, 3, 'Ram', 'Shyam', 'Aman']
