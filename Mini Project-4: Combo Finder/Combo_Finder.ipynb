# %% [markdown]
# <a href="https://colab.research.google.com/github/AryanK0/Thapar-Summer-School/blob/main/Mini%20Project-4%3A%20Combo%20Finder/Combo_Finder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
items = {'p1':10, 'p2':15, 'p3':20, 'p4':25, 'p5':30, 'p6':35, 'p7':50, 'p8':40, 'p9':55, 'p10':60, 'p11':65, 'p12':75, 'p13':70, 'p14':45}

# %%
from itertools import combinations

# %%
l = []
keys = list(items.keys())

for i in range (1, len(keys) + 1):
  for j in combinations(keys, i):
    total = sum(items[k] for k in j)
    if (290 <= total <= 310):
      l.append(j)

print("total subsets = ", len(l))
for i in l:
  print(i)
# Out:
# total subsets =  1796
# ('p3', 'p10', 'p11', 'p12', 'p13')
# ('p4', 'p9', 'p11', 'p12', 'p13')
# ('p4', 'p10', 'p11', 'p12', 'p13')
# ('p5', 'p7', 'p11', 'p12', 'p13')
# ('p5', 'p9', 'p10', 'p12', 'p13')
# ('p5', 'p9', 'p11', 'p12', 'p13')
# ('p5', 'p10', 'p11', 'p12', 'p13')
# ('p6', 'p7', 'p10', 'p12', 'p13')
# ('p6', 'p7', 'p11', 'p12', 'p13')
# ('p6', 'p9', 'p10', 'p11', 'p12')
# ('p6', 'p9', 'p10', 'p12', 'p13')
# ('p6', 'p9', 'p11', 'p12', 'p13')
# ('p6', 'p10', 'p11', 'p12', 'p13')
# ('p6', 'p11', 'p12', 'p13', 'p14')
# ('p7', 'p8', 'p9', 'p12', 'p13')
# ('p7', 'p8', 'p10', 'p11', 'p12')
# ('p7', 'p8', 'p10', 'p12', 'p13')
# ('p7', 'p8', 'p11', 'p12', 'p13')
# ('p7', 'p9', 'p10', 'p11', 'p12')
# ('p7', 'p9', 'p10', 'p11', 'p13')
# ('p7', 'p9', 'p10', 'p12', 'p13')
# ('p7', 'p9', 'p11', 'p12', 'p14')
# ('p7', 'p9', 'p12', 'p13', 'p14')
# ('p7', 'p10', 'p11', 'p12', 'p14')
# ('p7', 'p10', 'p11', 'p13', 'p14')
# ('p7', 'p10', 'p12', 'p13', 'p14')
# ...
